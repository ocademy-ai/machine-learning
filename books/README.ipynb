# %%
# Install the necessary dependencies

import os
import sys
# !{sys.executable} -m pip install --quiet pandas langcodes langcodes[data] tabulate

module_path = os.path.abspath(os.path.join('../'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
from IPython.core.display import Markdown
from lib.utils.awesome_list import *
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# /Users/zhangqi/ws/machine-learning/lib/utils/awesome_list.py:74: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   result.append('<a href="{0}">{1}</a>'.format(url, text) if url is not '' else text)

# %% [markdown]
# # Awesome Free AI Learning Resource

# %%
# Render the output

df = pd.read_csv('./data.csv')

excluded_columns = ['platformSrc', 'id', 'source',
                    'createdAt', 'authorSrc',
                    'description', 'license', 'updatedAt']
df = apply_common_style(df, excluded_columns)

display(Markdown(df.to_markdown()))
# Out:
# |    | Title                                                                                                             | Author                                            | Price   | Topic               | Platform                                                  | Language   | Level       | Label                     | Licence   |
# |---:|:------------------------------------------------------------------------------------------------------------------|:--------------------------------------------------|:--------|:--------------------|:----------------------------------------------------------|:-----------|:------------|:--------------------------|:----------|
# |  1 | <a href="https://info.deeplearning.ai/machine-learning-yearning-book#MYL-form">Machine Learning Yearning Book</a> | <a href="https://www.andrewng.org/">Andrew Ng</a> | 🟩 Free | 🧠 Machine learning | <a href="https://www.deeplearning.ai/">DeepLearningAI</a> | 🇺🇸 English | 🟩 Beginner | 🧠 Machine learning 🤖 AI |           |
