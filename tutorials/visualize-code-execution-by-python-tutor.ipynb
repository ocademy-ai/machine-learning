# %% [markdown]
# # Visualize code execution by Python Tutor
#
# [Python Tutor](https://pythontutor.com/) is a web app that helps programmers visualize code execution to understand bugs and optimize performance. You can Visualize the code execution frame by frame with Python Tutor, which supports multiple programming languages, making it valuable for both beginners and experienced programmers. It includes below key features.
#
# * 🧑‍💻 It supports Python 2 and 3, C, C++, Java, JavaScript, TypeScript, and Ruby.
# * 🤝 Users can collaborate in real-time.
# * 📈 It's an excellent tool for beginners and experienced programmers.
# * 📝 The process involves selecting a language, writing code, and running the visualization.
# * ⏯️ Users can control the visualization speed, pause, and edit code as needed.
# * 🔄 "Live Programming Mode" allows code editing during visualization.
# * 🚀 It's a valuable resource for learning and debugging code.

# %% [markdown]
# ## Get started

# %%
# Install the necessary dependencies

import os
import sys
# !{sys.executable} -m pip install --quiet ipython tutormagic

from IPython.display import HTML

# %% [markdown]
# ## First glimpse: visualize Towers of Hanoi
#
# Visualizing is super easy at Python Tutor! You can go to the Python Tutor website from this [quicklink](https://pythontutor.com/render.html#code=%23%20move%20a%20stack%20of%20n%20disks%20from%20stack%20a%20to%20stack%20b,%0A%23%20using%20tmp%20as%20a%20temporary%20stack%0Adef%20TowerOfHanoi%28n,%20a,%20b,%20tmp%29%3A%0A%20%20%20%20if%20n%20%3D%3D%201%3A%0A%20%20%20%20%20%20%20%20b.append%28a.pop%28%29%29%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20TowerOfHanoi%28n-1,%20a,%20tmp,%20b%29%0A%20%20%20%20%20%20%20%20b.append%28a.pop%28%29%29%0A%20%20%20%20%20%20%20%20TowerOfHanoi%28n-1,%20tmp,%20b,%20a%29%0A%20%20%20%20%20%20%20%20%0Astack1%20%3D%20%5B4,3,2,1%5D%0Astack2%20%3D%20%5B%5D%0Astack3%20%3D%20%5B%5D%0A%20%20%20%20%20%20%0A%23%20transfer%20stack1%20to%20stack3%20using%20Tower%20of%20Hanoi%20rules%0ATowerOfHanoi%28len%28stack1%29,%20stack1,%20stack3,%20stack2%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false) or use below embedded iframe directly to try it out.

# %%
display(HTML("""
  <iframe width="1000" height="800" scrolling="no" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=%23%20move%20a%20stack%20of%20n%20disks%20from%20stack%20a%20to%20stack%20b,%0A%23%20using%20tmp%20as%20a%20temporary%20stack%0Adef%20TowerOfHanoi%28n,%20a,%20b,%20tmp%29%3A%0A%20%20%20%20if%20n%20%3D%3D%201%3A%0A%20%20%20%20%20%20%20%20b.append%28a.pop%28%29%29%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20TowerOfHanoi%28n-1,%20a,%20tmp,%20b%29%0A%20%20%20%20%20%20%20%20b.append%28a.pop%28%29%29%0A%20%20%20%20%20%20%20%20TowerOfHanoi%28n-1,%20tmp,%20b,%20a%29%0A%20%20%20%20%20%20%20%20%0Astack1%20%3D%20%5B4,3,2,1%5D%0Astack2%20%3D%20%5B%5D%0Astack3%20%3D%20%5B%5D%0A%20%20%20%20%20%20%0A%23%20transfer%20stack1%20to%20stack3%20using%20Tower%20of%20Hanoi%20rules%0ATowerOfHanoi%28len%28stack1%29,%20stack1,%20stack3,%20stack2%29&codeDivHeight=400&codeDivWidth=350&cumulative=false&curInstr=39&heapPrimitives=nevernest&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false"> </iframe>
"""))
# Out:
#   <iframe width="1000" height="800" scrolling="no" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=%23%20move%20a%20stack%20of%20n%20disks%20from%20stack%20a%20to%20stack%20b,%0A%23%20using%20tmp%20as%20a%20temporary%20stack%0Adef%20TowerOfHanoi%28n,%20a,%20b,%20tmp%29%3A%0A%20%20%20%20if%20n%20%3D%3D%201%3A%0A%20%20%20%20%20%20%20%20b.append%28a.pop%28%29%29%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20TowerOfHanoi%28n-1,%20a,%20tmp,%20b%29%0A%20%20%20%20%20%20%20%20b.append%28a.pop%28%29%29%0A%20%20%20%20%20%20%20%20TowerOfHanoi%28n-1,%20tmp,%20b,%20a%29%0A%20%20%20%20%20%20%20%20%0Astack1%20%3D%20%5B4,3,2,1%5D%0Astack2%20%3D%20%5B%5D%0Astack3%20%3D%20%5B%5D%0A%20%20%20%20%20%20%0A%23%20transfer%20stack1%20to%20stack3%20using%20Tower%20of%20Hanoi%20rules%0ATowerOfHanoi%28len%28stack1%29,%20stack1,%20stack3,%20stack2%29&codeDivHeight=400&codeDivWidth=350&cumulative=false&curInstr=39&heapPrimitives=nevernest&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&te
# ...

# %% [markdown]
# ## Live editing
#
# The visualized code could be modified at any time through the live editing interface.
#
# [![image.png](attachment:0106a19c-903e-46a7-856c-c428db8f58ef.png)](https://excalidraw.com/#json=iB0k2KVM4J_Sl7GmFSdSc,CKdcVUjCp94tvIY6Unp9zA)

# %% [markdown]
# You can also bring your own code by following above steps. Here is an example to construct string **`Ocademy`** from a nested list of letters.

# %%
display(HTML("""
  <iframe width="1000" height="650" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=%23%20Tutorial%20code%20from%20Prof.%20Peter%20Wentworth%0A%23%20Rhodes%20University,%20South%20Africa%20%28http%3A//www.ru.ac.za/%29%0A%0Adef%20sumList%28xs%29%3A%0A%20%20%20%20'''%0A%20%20%20%20Sum%20a%20list%20that%20can%20contain%20nested%20lists.%0A%20%20%20%20Precondition%3A%20All%20leaf%20elements%20are%20numbers.%0A%20%20%20%20'''%0A%20%20%20%20sum%20%3D%20''%0A%20%20%20%20for%20e%20in%20xs%3A%0A%20%20%20%20%20%20%20%20if%20type%28e%29%20is%20list%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20print%28%28%22Calling%20sumList%28%25s%29%20recursively%22%20%25%20e%29%29%0A%20%20%20%20%20%20%20%20%20%20%20%20v%20%3D%20sumList%28e%29%0A%20%20%20%20%20%20%20%20%20%20%20%20print%28%28%22sumList%28%25s%29%20returned%20%25s%22%20%25%20%28e,%20v%29%29%29%0A%20%20%20%20%20%20%20%20%20%20%20%20sum%20%2B%3D%20v%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20sum%20%2B%3D%20e%0A%20%20%20%20return%20sum%0A%0A%0AtestData%20%3D%20%5B'O',%20%5B'c',%20'a',%20%5B'd'%5D,%20'e'%5D,%20'm',%20'y'%5D%0Aprint%28%28%22Calling%20sumList%28%25s%29%22%20%25%20testData%29%29%0Aresult%20%3D%20sumList%28testData%29%0Aprint%28%28%22Final%20sum%20of%20all%20numbers%20in%20initial%20list%20is%20%25s%22%20%25%20result%29%29&codeDivHeight=400&codeDivWidth=350&cumulative=false&curInstr=27&heapPrimitives=nevernest&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false"> </iframe>
"""))
# Out:
#   <iframe width="1000" height="650" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=%23%20Tutorial%20code%20from%20Prof.%20Peter%20Wentworth%0A%23%20Rhodes%20University,%20South%20Africa%20%28http%3A//www.ru.ac.za/%29%0A%0Adef%20sumList%28xs%29%3A%0A%20%20%20%20'''%0A%20%20%20%20Sum%20a%20list%20that%20can%20contain%20nested%20lists.%0A%20%20%20%20Precondition%3A%20All%20leaf%20elements%20are%20numbers.%0A%20%20%20%20'''%0A%20%20%20%20sum%20%3D%20''%0A%20%20%20%20for%20e%20in%20xs%3A%0A%20%20%20%20%20%20%20%20if%20type%28e%29%20is%20list%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20print%28%28%22Calling%20sumList%28%25s%29%20recursively%22%20%25%20e%29%29%0A%20%20%20%20%20%20%20%20%20%20%20%20v%20%3D%20sumList%28e%29%0A%20%20%20%20%20%20%20%20%20%20%20%20print%28%28%22sumList%28%25s%29%20returned%20%25s%22%20%25%20%28e,%20v%29%29%29%0A%20%20%20%20%20%20%20%20%20%20%20%20sum%20%2B%3D%20v%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20sum%20%2B%
# ...

# %% [markdown]
# ## Visualize other programming languages
#
# To visualize other languages is just simple as Python.
#
# [![image.png](attachment:96a516b1-3c6f-4ede-a523-f1f015bbecea.png)](https://excalidraw.com/#json=4vWB9DzPWXZkASOu8el-N,6HWhGE8PnICvaxytO28Cpw)
#
# And here is a live example of visualizing a forest implemented by Java.

# %%
display(HTML("""
    <iframe width="1000" height="1000" scrolling="no" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=//%20Princeton%20COS%20126%20Written%20Exam%202,%20Fall%202010,%20Question%203%0A//%20note%3A%20this%20is%20a%20proof-of-concept,%20but%20to%20do%20this%20on%0A//%20paper%20you%20would%20instead%20skip%20as%20many%20internal%20steps%20of%0A//%20root,%20merge,%20and%20merged%20as%20possible%0A%0Apublic%20class%20Node%20%7B%0A%20%20%20private%20Node%20next%3B%0A%20%20%20private%20int%20index%3B%0A%20%20%20private%20Node%20root%28%29%20%7B%0A%20%20%20%20%20%20if%20%28next%20%3D%3D%20null%29%20return%20this%3B%0A%20%20%20%20%20%20return%20next.root%28%29%3B%0A%20%20%20%7D%0A%20%20%20public%20static%20void%20merge%28Node%20a,%20Node%20b%29%20%7B%0A%20%20%20%20%20%20a.root%28%29.next%20%3D%20b.root%28%29%3B%0A%20%20%20%7D%0A%20%20%20public%20static%20boolean%20merged%28Node%20a,%20Node%20b%29%20%7B%0A%20%20%20%20%20%20return%20a.root%28%29%20%3D%3D%20b.root%28%29%3B%0A%20%20%20%7D%0A%20%20%20public%20static%20void%20main%28String%5B%5D%20args%29%20%7B%0A%20%20%20%20%20%20Node%5B%5D%20f%20%3D%20new%20Node%5B8%5D%3B%0A%20%20%20%20%20%20for%20%28int%20i%3D0%3B%20i%3C8%3B%20i%2B%2B%29%20%7Bf%5Bi%5D%20%3D%20new%20Node%28%29%3B%20f%5Bi%5D.index%3Di%3B%7D%0A%20%20%20%20%20%20merge%28f%5B0%5D,%20f%5B3%5D%29%3B%0A%20%20%20%20%20%20merge%28f%5B1%5D,%20f%5B2%5D%29%3B%0A%20%20%20%20%20%20merge%28f%5B1%5D,%20f%5B4%5D%29%3B%0A%20%20%20%20%20%20merge%28f%5B5%5D,%20f%5B6%5D%29%3B%0A%20%20%20%20%20%20merge%28f%5B3%5D,%20f%5B4%5D%29%3B%0A%20%20%20%20%20%20merge%28f%5B7%5D,%20f%5B5%5D%29%3B%0A%20%20%20%20%20%20%0A%20%20%20%20%20%20System.out.println%28merged%28f%5B0%5D,%20f%5B3%5D%29%29%3B%0A%20%20%20%20%20%20System.out.println%28merged%28f%5B0%5D,%20f%5B7%5D%29%29%3B%0A%20%20%20%20%20%20System.out.println%28merged%28f%5B1%5D,%20f%5B3%5D%29%29%3B%0A%20%20%20%20%20%20System.out.println%28merged%28f%5B4%5D,%20f%5B5%5D%29%29%3B%0A%20%20%20%7D%0A%7D&codeDivHeight=400&codeDivWidth=350&cumulative=false&curInstr=121&heapPrimitives=nevernest&origin=opt-frontend.js&py=java&rawInputLstJSON=%5B%5D&textReferences=false"> </iframe>
"""))
# Out:
#     <iframe width="1000" height="1000" scrolling="no" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=//%20Princeton%20COS%20126%20Written%20Exam%202,%20Fall%202010,%20Question%203%0A//%20note%3A%20this%20is%20a%20proof-of-concept,%20but%20to%20do%20this%20on%0A//%20paper%20you%20would%20instead%20skip%20as%20many%20internal%20steps%20of%0A//%20root,%20merge,%20and%20merged%20as%20possible%0A%0Apublic%20class%20Node%20%7B%0A%20%20%20private%20Node%20next%3B%0A%20%20%20private%20int%20index%3B%0A%20%20%20private%20Node%20root%28%29%20%7B%0A%20%20%20%20%20%20if%20%28next%20%3D%3D%20null%29%20return%20this%3B%0A%20%20%20%20%20%20return%20next.root%28%29%3B%0A%20%20%20%7D%0A%20%20%20public%20static%20void%20merge%28Node%20a,%20Node%20b%29%20%7B%0A%20%20%20%20%20%20a.root%28%29.next%20%3D%20b.root%28%29%3B%0A%20%20%20%7D%0A%20%20%20public%20static%20boolean%20merged%28Node%20a,%20Node%20b%29%20%7B%0A%20%20%20%20%20%20return%20a.root%28%29%20%3D%3D%20b.root%28%29%3B%0A%
# ...

# %% [markdown]
# ## Python Tutor + Jupyter Notebooks
#
# There are multiple ways to integrate Python Tutor with Jupyter Notebooks, so you can generate Python Tutor visualization directly inside a notebook. Below is an example of [tutormagic](https://github.com/kikocorreoso/tutormagic). Or you can use [jupyterlab-pytutor](https://github.com/jupyterlab-contrib/jupyterlab-pytutor) with Jupyter Lab.

# %%
# %load_ext tutormagic

# %%
# %%tutor --lang python3 -h 700
#
# x = [1, 2, 3]
# y = [4, 5, 6]
# z = y
# y = x
# x = z
#
# x = [1, 2, 3] # a different [1, 2, 3] list!
# y = x
# x.append(4)
# y.append(5)
# z = [1, 2, 3, 4, 5] # a different list!
# x.append(6)
# y.append(7)
# y = "hello"
#
#
# def foo(lst):
#     lst.append("Hello, Ocademy!")
#     bar(lst)
#
# def bar(myLst):
#     print(myLst)
#
# foo(x)
# foo(z)
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://pythontutor.com/iframe-embed.html#code=%0Ax%20%3D%20%5B1%2C%202%2C%203%5D%0Ay%20%3D%20%5B4%2C%205%2C%206%5D%0Az%20%3D%20y%0Ay%20%3D%20x%0Ax%20%3D%20z%0A%0Ax%20%3D%20%5B1%2C%202%2C%203%5D%20%23%20a%20different%20%5B1%2C%202%2C%203%5D%20list%21%0Ay%20%3D%20x%0Ax.append%284%29%0Ay.append%285%29%0Az%20%3D%20%5B1%2C%202%2C%203%2C%204%2C%205%5D%20%23%20a%20different%20list%21%0Ax.append%286%29%0Ay.append%287%29%0Ay%20%3D%20%22hello%22%0A%0A%0Adef%20foo%28lst%29%3A%0A%20%20%20%20lst.append%28%22Hello%2C%20Ocademy%21%22%29%0A%20%20%20%20bar%28lst%29%0A%0Adef%20bar%28myLst%29%3A%0A%20%20%20%20print%28myLst%29%0A%0Afoo%28x%29%0Afoo%28z%29%0A&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=3&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25"
#             frameborder="0"
#             allowfullscreen
#
# ...
